# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1 BASICS

# %%
plt.style.use('default')
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()

print(s.plot())
print(s.plot().get_figure())
# Out:
# AxesSubplot(0.125,0.11;0.775x0.77)
# Figure(640x480)

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10))
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2 BAR PLOTS

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7)
data.plot.barh(ax=axes[1], color='k', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(6, 4),
                  index=['one', 'two', 'three', 'four', 'five', 'six'],
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus'))
print(df)
df.plot.bar()
df.plot(kind='barh', stacked=True, alpha=0.5)
# Out:
# Genus         A         B         C         D
# one    0.719964  0.167960  0.626919  0.261520
# two    0.396401  0.352992  0.332171  0.473338
# three  0.591189  0.788069  0.133881  0.824370
# four   0.294316  0.727164  0.291119  0.196937
# five   0.306201  0.561069  0.824481  0.242799
# six    0.777825  0.100449  0.935488  0.669586
# <AxesSubplot:>

# %% [markdown]
# ### 3 HISTOGRAMS & DENSITIES

# %%
tips = sns.load_dataset('tips')
print(tips.head())
tips['tip_pct'] = 100 * tips['tip'] / tips['total_bill']

tips['tip_pct'].plot.hist(bins=50)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <AxesSubplot:ylabel='Frequency'>

# %%
tips['tip_pct'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
